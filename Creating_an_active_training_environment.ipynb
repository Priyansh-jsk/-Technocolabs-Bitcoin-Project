# %%
"""Utility functions used in Activity 6."""

import numpy as np


def create_groups(data, group_size=7):
    """Create distinct groups from a continuous series.

    Parameters
    ----------
    data: np.array
        Series of continious observations.

    group_size: int, default 7
        Determines how large the groups are. That is,
        how many observations each group contains.

    Returns
    -------
    A Numpy array object.
    """
    samples = list()
    for i in range(0, len(data), group_size):
        sample = list(data[i:i + group_size])
        if len(sample) == group_size:
            samples.append(np.array(sample).reshape(1, group_size).tolist())

    a = np.array(samples)
    return a.reshape(1, a.shape[0], group_size)


def split_lstm_input(groups):
    """Split groups in a format expected by the LSTM layer.

    Parameters
    ----------
    groups: np.array
        Numpy array with the organized sequences.

    Returns
    -------
    X, Y: np.array
        Numpy arrays with the shapes required by
        the LSTM layer. X with (1, a - 1, b)
        and Y with (1, b). Where a is the total
        number of groups in `group` and b the
        number of observations per group.
    """
    X = groups[0:, :-1].reshape(1, groups.shape[1] - 1, groups.shape[2])
    Y = groups[0:, -1:][0]

    return X, Y


def mape(A, B):
    """Calculate the mean absolute percentage error from two series."""
    return np.mean(np.abs((A - B) / A)) * 100


def rmse(A, B):
    """Calculate the root mean square error from two series."""
    return np.sqrt(np.square(np.subtract(A, B)).mean())

# %%
# %autosave 5

#  Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-white')

from keras.models import load_model
from keras.callbacks import TensorBoard
from datetime import datetime, timedelta

np.random.seed(0)
# Out:
# Autosaving every 5 seconds

# %%
#  Load datasets
train = pd.read_csv('/content/train_dataset.csv - train_dataset.csv.csv')
test = pd.read_csv('/content/test_dataset.csv - test_dataset.csv.csv')

# %%
#  Group data into groups containing seven observations
train_data = create_groups(
    train['close_point_relative_normalization'][2:].values)

test_data = create_groups(
    test['close_point_relative_normalization'][:-3].values)

# %%
#  Reshape the data in the format expected by the LSTM layer
X_train, Y_train = split_lstm_input(train_data)

# %% [markdown]
# ## Re-train Model with TensorBoard

# %%
def train_model(model, X, Y, epochs, version, run_number):
    """Training a model with TensorBoard callback.

    This function names each run of the model
    using the TensorBoard naming conventions.

    Parameters
    ----------
    model: Keras model instance
        Compiled Keras model.

    X, Y: np.array
        Series of observations to be used in
        the training process.

    epochs: int
        The number of epochs to train the
        model for.

    version: int
        Version of the model to run.

    run_number: int
        The number of the run. Used in case
        the same model version is run again.
    """
    model_name = f'bitcoin_lstm_v{version}_run_{run_number}'
    tensorboard = TensorBoard(log_dir=f'./logs/{model_name}')

    #  TASK:
    #  Modify the `fit` method to include a TensorBoard callback.
    #
    model_history = model.fit(
        x=X, y=Y,
        batch_size=1, epochs=epochs,
        shuffle=False)

    return model_history

# %%
#  Load previously trained network
model = load_model('bitcoin_lstm_v0.h5')

# %%
#  Retrain network
model_history = train_model(model=model,
                            X=X_train, Y=Y_train,
                            epochs=1000,
                            version=0, run_number=2)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 2/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 3/1000
# 1/1 [==============================] - 0s 973us/step - loss: 0.0016
# Epoch 4/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0014
# Epoch 5/1000
# 1/1 [==============================] - 0s 1000us/step - loss: 0.0012
# Epoch 6/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0011
# Epoch 7/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4825e-04
# Epoch 8/1000
# 1/1 [==============================] - 0s 968us/step - loss: 8.3270e-04
# Epoch 9/1000
# 1/1 [==============================] - 0s 967us/step - loss: 7.3157e-04
# Epoch 10/1000
# 1/1 [==============================] - 0s 982us/step - loss: 6.4272e-04
# Epoch 11/1000
# 1/1 [==============================] - 0s 991us/step - loss: 5.6445e-04
# Epoch 12/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9539e-04
# Epoch 13/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3437e-04
# Epoch 14/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8040e-04
# Epoch 15/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3262e-04
# Epoch 16/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9027e-04
# Epoch 17/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5271e-04
# Epoch 18/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1938e-04
# Epoch 19/1000
# 1/1 [==============================] - 0s 956us/step - loss: 1.8981e-04
# Epoch 20/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6360e-04
# Epoch 21/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4038e-04
# Epoch 22/1000
# 1/1 [==============================] - 0s 969us/step - loss: 1.1986e-04
# Epoch 23/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0179e-04
# Epoch 24/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 8.5911e-05
# Epoch 25/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2032e-05
# Epoch 26/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9957e-05
# Epoch 27/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9511e-05
# Epoch 28/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0535e-05
# Epoch 29/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2876e-05
# Epoch 30/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6395e-05
# Epoch 31/1000
# 1/1 [==============================] - 0s 1000us/step - loss: 2.0958e-05
# Epoch 32/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6444e-05
# Epoch 33/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2735e-05
# Epoch 34/1000
# 1/1 [==============================] - 0s 986us/step - loss: 9.7257e-06
# Epoch 35/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3161e-06
# Epoch 36/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4195e-06
# Epoch 37/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0111e-06
# Epoch 38/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6114e-06
# Epoch 39/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.0381e-06
# Epoch 40/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.1617e-06
# Epoch 41/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2371e-06
# Epoch 42/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8354e-06
# Epoch 43/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0242e-06
# Epoch 44/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6893e-07
# Epoch 45/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6438e-07
# Epoch 46/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8260e-07
# Epoch 47/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6150e-07
# Epoch 48/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2957e-07
# Epoch 49/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8519e-07
# Epoch 50/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4774e-07
# Epoch 51/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5382e-06
# Epoch 52/1000
# 1/1 [==============================] - 0s 967us/step - loss: 2.5682e-06
# Epoch 53/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3791e-06
# Epoch 54/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0182e-06
# Epoch 55/1000
# 1/1 [==============================] - 0s 953us/step - loss: 3.3410e-06
# Epoch 56/1000
# 1/1 [==============================] - 0s 934us/step - loss: 2.8592e-06
# Epoch 57/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0145e-06
# Epoch 58/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6663e-06
# Epoch 59/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3171e-06
# Epoch 60/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2547e-06
# Epoch 61/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2041e-06
# Epoch 62/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3675e-06
# Epoch 63/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5417e-06
# Epoch 64/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9724e-06
# Epoch 65/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3367e-06
# Epoch 66/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9692e-06
# Epoch 67/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1952e-06
# Epoch 68/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6767e-06
# Epoch 69/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5562e-06
# Epoch 70/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7929e-06
# Epoch 71/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1817e-06
# Epoch 72/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7976e-06
# Epoch 73/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0302e-06
# Epoch 74/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6754e-06
# Epoch 75/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3195e-06
# Epoch 76/1000
# 1/1 [==============================] - 0s 937us/step - loss: 1.2418e-06
# Epoch 77/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2120e-06
# Epoch 78/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4793e-06
# Epoch 79/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0539e-06
# Epoch 80/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7221e-06
# Epoch 81/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.0109e-06
# Epoch 82/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6179e-06
# Epoch 83/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 5.6071e-06
# Epoch 84/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1984e-06
# Epoch 85/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8398e-06
# Epoch 86/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3038e-06
# Epoch 87/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9596e-06
# Epoch 88/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8800e-06
# Epoch 89/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9205e-06
# Epoch 90/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0578e-06
# Epoch 91/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3296e-06
# Epoch 92/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5908e-06
# Epoch 93/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9419e-06
# Epoch 94/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9387e-06
# Epoch 95/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9315e-06
# Epoch 96/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5567e-06
# Epoch 97/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4985e-06
# Epoch 98/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4642e-06
# Epoch 99/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1986e-06
# Epoch 100/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3047e-06
# Epoch 101/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8313e-06
# Epoch 102/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1515e-06
# Epoch 103/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1616e-06
# Epoch 104/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6241e-06
# Epoch 105/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9743e-06
# Epoch 106/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5619e-06
# Epoch 107/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5602e-06
# Epoch 108/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6632e-06
# Epoch 109/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0194e-06
# Epoch 110/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4951e-06
# Epoch 111/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0861e-06
# Epoch 112/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4052e-06
# Epoch 113/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3936e-06
# Epoch 114/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1917e-06
# Epoch 115/1000
# 1/1 [==============================] - 0s 932us/step - loss: 2.9486e-06
# Epoch 116/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8737e-06
# Epoch 117/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7028e-06
# Epoch 118/1000
# 1/1 [==============================] - 0s 998us/step - loss: 2.7531e-06
# Epoch 119/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6824e-06
# Epoch 120/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0155e-06
# Epoch 121/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3325e-06
# Epoch 122/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3482e-06
# Epoch 123/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7979e-06
# Epoch 124/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9784e-06
# Epoch 125/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6307e-06
# Epoch 126/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7718e-06
# Epoch 127/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8763e-06
# Epoch 128/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5366e-06
# Epoch 129/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3517e-06
# Epoch 130/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5096e-06
# Epoch 131/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7938e-06
# Epoch 132/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3258e-06
# Epoch 133/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9220e-06
# Epoch 134/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5979e-06
# Epoch 135/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7599e-06
# Epoch 136/1000
# 1/1 [==============================] - 0s 957us/step - loss: 3.5146e-06
# Epoch 137/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0401e-06
# Epoch 138/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7173e-06
# Epoch 139/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7191e-06
# Epoch 140/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8075e-06
# Epoch 141/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0900e-06
# Epoch 142/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0818e-06
# Epoch 143/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2862e-06
# Epoch 144/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1832e-06
# Epoch 145/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6302e-06
# Epoch 146/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8033e-06
# Epoch 147/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1899e-06
# Epoch 148/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5353e-06
# Epoch 149/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0369e-06
# Epoch 150/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2116e-06
# Epoch 151/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8463e-06
# Epoch 152/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5428e-06
# Epoch 153/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5978e-06
# Epoch 154/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7980e-06
# Epoch 155/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2662e-06
# Epoch 156/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7310e-06
# Epoch 157/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3520e-06
# Epoch 158/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6150e-06
# Epoch 159/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5503e-06
# Epoch 160/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1494e-06
# Epoch 161/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8368e-06
# Epoch 162/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8335e-06
# Epoch 163/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9497e-06
# Epoch 164/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2050e-06
# Epoch 165/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0709e-06
# Epoch 166/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0825e-06
# Epoch 167/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7913e-06
# Epoch 168/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9936e-06
# Epoch 169/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1430e-06
# Epoch 170/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7532e-06
# Epoch 171/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6596e-06
# Epoch 172/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5050e-06
# Epoch 173/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6720e-06
# Epoch 174/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2186e-06
# Epoch 175/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7342e-06
# Epoch 176/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6382e-06
# Epoch 177/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6798e-06
# Epoch 178/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0406e-06
# Epoch 179/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4195e-06
# Epoch 180/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0111e-06
# Epoch 181/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4345e-06
# Epoch 182/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6174e-06
# Epoch 183/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3628e-06
# Epoch 184/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0655e-06
# Epoch 185/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0026e-06
# Epoch 186/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0198e-06
# Epoch 187/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1456e-06
# Epoch 188/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9036e-06
# Epoch 189/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8250e-06
# Epoch 190/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5139e-06
# Epoch 191/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6345e-06
# Epoch 192/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7508e-06
# Epoch 193/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3906e-06
# Epoch 194/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6196e-06
# Epoch 195/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7762e-06
# Epoch 196/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0179e-06
# Epoch 197/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5184e-06
# Epoch 198/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8861e-06
# Epoch 199/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6695e-06
# Epoch 200/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5820e-06
# Epoch 201/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8616e-06
# Epoch 202/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2117e-06
# Epoch 203/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7887e-06
# Epoch 204/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3096e-06
# Epoch 205/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6608e-06
# Epoch 206/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5165e-06
# Epoch 207/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2285e-06
# Epoch 208/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1178e-06
# Epoch 209/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0535e-06
# Epoch 210/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0806e-06
# Epoch 211/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7673e-06
# Epoch 212/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6328e-06
# Epoch 213/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3179e-06
# Epoch 214/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3910e-06
# Epoch 215/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4697e-06
# Epoch 216/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0556e-06
# Epoch 217/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4382e-06
# Epoch 218/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8488e-06
# Epoch 219/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2577e-06
# Epoch 220/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7781e-06
# Epoch 221/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0411e-06
# Epoch 222/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7331e-06
# Epoch 223/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5384e-06
# Epoch 224/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7407e-06
# Epoch 225/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0751e-06
# Epoch 226/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6420e-06
# Epoch 227/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2138e-06
# Epoch 228/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6695e-06
# Epoch 229/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6049e-06
# Epoch 230/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3300e-06
# Epoch 231/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1992e-06
# Epoch 232/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0815e-06
# Epoch 233/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0354e-06
# Epoch 234/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6623e-06
# Epoch 235/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4797e-06
# Epoch 236/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1575e-06
# Epoch 237/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1962e-06
# Epoch 238/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2488e-06
# Epoch 239/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7708e-06
# Epoch 240/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2132e-06
# Epoch 241/1000
# 1/1 [==============================] - 0s 959us/step - loss: 3.7986e-06
# Epoch 242/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4081e-06
# Epoch 243/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9947e-06
# Epoch 244/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1905e-06
# Epoch 245/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8138e-06
# Epoch 246/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5335e-06
# Epoch 247/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6677e-06
# Epoch 248/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9853e-06
# Epoch 249/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5501e-06
# Epoch 250/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1529e-06
# Epoch 251/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6658e-06
# Epoch 252/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6498e-06
# Epoch 253/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3864e-06
# Epoch 254/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2563e-06
# Epoch 255/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0960e-06
# Epoch 256/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9847e-06
# Epoch 257/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5581e-06
# Epoch 258/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3364e-06
# Epoch 259/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0129e-06
# Epoch 260/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0317e-06
# Epoch 261/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0749e-06
# Epoch 262/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5503e-06
# Epoch 263/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0125e-06
# Epoch 264/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6994e-06
# Epoch 265/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4845e-06
# Epoch 266/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1518e-06
# Epoch 267/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3114e-06
# Epoch 268/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8867e-06
# Epoch 269/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5453e-06
# Epoch 270/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6332e-06
# Epoch 271/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9409e-06
# Epoch 272/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5152e-06
# Epoch 273/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1452e-06
# Epoch 274/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6723e-06
# Epoch 275/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6652e-06
# Epoch 276/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4036e-06
# Epoch 277/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2851e-06
# Epoch 278/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0798e-06
# Epoch 279/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9050e-06
# Epoch 280/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4361e-06
# Epoch 281/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1898e-06
# Epoch 282/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8776e-06
# Epoch 283/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8917e-06
# Epoch 284/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9407e-06
# Epoch 285/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3913e-06
# Epoch 286/1000
# 1/1 [==============================] - 0s 983us/step - loss: 2.8627e-06
# Epoch 287/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6026e-06
# Epoch 288/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5107e-06
# Epoch 289/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2451e-06
# Epoch 290/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3897e-06
# Epoch 291/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9356e-06
# Epoch 292/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5588e-06
# Epoch 293/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6272e-06
# Epoch 294/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9425e-06
# Epoch 295/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5407e-06
# Epoch 296/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1990e-06
# Epoch 297/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6953e-06
# Epoch 298/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6573e-06
# Epoch 299/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3873e-06
# Epoch 300/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2808e-06
# Epoch 301/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0203e-06
# Epoch 302/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7856e-06
# Epoch 303/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2921e-06
# Epoch 304/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0389e-06
# Epoch 305/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7518e-06
# Epoch 306/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7741e-06
# Epoch 307/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8399e-06
# Epoch 308/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2833e-06
# Epoch 309/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7646e-06
# Epoch 310/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5307e-06
# Epoch 311/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5086e-06
# Epoch 312/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2837e-06
# Epoch 313/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4244e-06
# Epoch 314/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9561e-06
# Epoch 315/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5674e-06
# Epoch 316/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6416e-06
# Epoch 317/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9857e-06
# Epoch 318/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6234e-06
# Epoch 319/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3057e-06
# Epoch 320/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7256e-06
# Epoch 321/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6293e-06
# Epoch 322/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3458e-06
# Epoch 323/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2394e-06
# Epoch 324/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9147e-06
# Epoch 325/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6311e-06
# Epoch 326/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1346e-06
# Epoch 327/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8914e-06
# Epoch 328/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6394e-06
# Epoch 329/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6787e-06
# Epoch 330/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7667e-06
# Epoch 331/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2131e-06
# Epoch 332/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7043e-06
# Epoch 333/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4810e-06
# Epoch 334/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4899e-06
# Epoch 335/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2828e-06
# Epoch 336/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4264e-06
# Epoch 337/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9556e-06
# Epoch 338/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5720e-06
# Epoch 339/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6698e-06
# Epoch 340/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0605e-06
# Epoch 341/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7509e-06
# Epoch 342/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4428e-06
# Epoch 343/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7497e-06
# Epoch 344/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5859e-06
# Epoch 345/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2857e-06
# Epoch 346/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1596e-06
# Epoch 347/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7740e-06
# Epoch 348/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4596e-06
# Epoch 349/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9803e-06
# Epoch 350/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7587e-06
# Epoch 351/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5453e-06
# Epoch 352/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6043e-06
# Epoch 353/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7138e-06
# Epoch 354/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1646e-06
# Epoch 355/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6602e-06
# Epoch 356/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4355e-06
# Epoch 357/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4574e-06
# Epoch 358/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2602e-06
# Epoch 359/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4144e-06
# Epoch 360/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9486e-06
# Epoch 361/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5773e-06
# Epoch 362/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7052e-06
# Epoch 363/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1522e-06
# Epoch 364/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9013e-06
# Epoch 365/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5832e-06
# Epoch 366/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7609e-06
# Epoch 367/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5337e-06
# Epoch 368/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2104e-06
# Epoch 369/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0490e-06
# Epoch 370/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6198e-06
# Epoch 371/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2941e-06
# Epoch 372/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8444e-06
# Epoch 373/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6488e-06
# Epoch 374/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4705e-06
# Epoch 375/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5467e-06
# Epoch 376/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6716e-06
# Epoch 377/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1204e-06
# Epoch 378/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6097e-06
# Epoch 379/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3748e-06
# Epoch 380/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4125e-06
# Epoch 381/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2344e-06
# Epoch 382/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4078e-06
# Epoch 383/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9507e-06
# Epoch 384/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5875e-06
# Epoch 385/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7376e-06
# Epoch 386/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2407e-06
# Epoch 387/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0466e-06
# Epoch 388/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7077e-06
# Epoch 389/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7653e-06
# Epoch 390/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4811e-06
# Epoch 391/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1251e-06
# Epoch 392/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9245e-06
# Epoch 393/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4740e-06
# Epoch 394/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1521e-06
# Epoch 395/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7359e-06
# Epoch 396/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5641e-06
# Epoch 397/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4132e-06
# Epoch 398/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5002e-06
# Epoch 399/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6313e-06
# Epoch 400/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0660e-06
# Epoch 401/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5351e-06
# Epoch 402/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2828e-06
# Epoch 403/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3560e-06
# Epoch 404/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2201e-06
# Epoch 405/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4227e-06
# Epoch 406/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9746e-06
# Epoch 407/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6059e-06
# Epoch 408/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7553e-06
# Epoch 409/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3008e-06
# Epoch 410/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1583e-06
# Epoch 411/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8102e-06
# Epoch 412/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7780e-06
# Epoch 413/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4388e-06
# Epoch 414/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0401e-06
# Epoch 415/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8054e-06
# Epoch 416/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3527e-06
# Epoch 417/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0431e-06
# Epoch 418/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6573e-06
# Epoch 419/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5031e-06
# Epoch 420/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3696e-06
# Epoch 421/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4588e-06
# Epoch 422/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5854e-06
# Epoch 423/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9920e-06
# Epoch 424/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4262e-06
# Epoch 425/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1482e-06
# Epoch 426/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2843e-06
# Epoch 427/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2243e-06
# Epoch 428/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4696e-06
# Epoch 429/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0306e-06
# Epoch 430/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6375e-06
# Epoch 431/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7505e-06
# Epoch 432/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3046e-06
# Epoch 433/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2091e-06
# Epoch 434/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8892e-06
# Epoch 435/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8176e-06
# Epoch 436/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4220e-06
# Epoch 437/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9705e-06
# Epoch 438/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7077e-06
# Epoch 439/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2643e-06
# Epoch 440/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9705e-06
# Epoch 441/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6083e-06
# Epoch 442/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4636e-06
# Epoch 443/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3368e-06
# Epoch 444/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4190e-06
# Epoch 445/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5309e-06
# Epoch 446/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8965e-06
# Epoch 447/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2811e-06
# Epoch 448/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9621e-06
# Epoch 449/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1837e-06
# Epoch 450/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2415e-06
# Epoch 451/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5535e-06
# Epoch 452/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1280e-06
# Epoch 453/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6918e-06
# Epoch 454/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7270e-06
# Epoch 455/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2236e-06
# Epoch 456/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1666e-06
# Epoch 457/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9332e-06
# Epoch 458/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9045e-06
# Epoch 459/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4558e-06
# Epoch 460/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9363e-06
# Epoch 461/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6436e-06
# Epoch 462/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2129e-06
# Epoch 463/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9348e-06
# Epoch 464/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5884e-06
# Epoch 465/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4446e-06
# Epoch 466/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3137e-06
# Epoch 467/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3796e-06
# Epoch 468/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4683e-06
# Epoch 469/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7836e-06
# Epoch 470/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1072e-06
# Epoch 471/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7224e-06
# Epoch 472/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0275e-06
# Epoch 473/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2444e-06
# Epoch 474/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6699e-06
# Epoch 475/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2749e-06
# Epoch 476/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7847e-06
# Epoch 477/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7185e-06
# Epoch 478/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0605e-06
# Epoch 479/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0007e-06
# Epoch 480/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8957e-06
# Epoch 481/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0371e-06
# Epoch 482/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5664e-06
# Epoch 483/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9588e-06
# Epoch 484/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6217e-06
# Epoch 485/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1983e-06
# Epoch 486/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9341e-06
# Epoch 487/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5973e-06
# Epoch 488/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4469e-06
# Epoch 489/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3019e-06
# Epoch 490/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3430e-06
# Epoch 491/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4013e-06
# Epoch 492/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6618e-06
# Epoch 493/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9198e-06
# Epoch 494/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4433e-06
# Epoch 495/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7905e-06
# Epoch 496/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1816e-06
# Epoch 497/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8012e-06
# Epoch 498/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4766e-06
# Epoch 499/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9272e-06
# Epoch 500/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7490e-06
# Epoch 501/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8219e-06
# Epoch 502/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6151e-06
# Epoch 503/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6637e-06
# Epoch 504/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2084e-06
# Epoch 505/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8460e-06
# Epoch 506/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1170e-06
# Epoch 507/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6791e-06
# Epoch 508/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2315e-06
# Epoch 509/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9713e-06
# Epoch 510/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6396e-06
# Epoch 511/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4772e-06
# Epoch 512/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3077e-06
# Epoch 513/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3148e-06
# Epoch 514/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3349e-06
# Epoch 515/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5384e-06
# Epoch 516/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7345e-06
# Epoch 517/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1559e-06
# Epoch 518/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4760e-06
# Epoch 519/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9697e-06
# Epoch 520/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8627e-06
# Epoch 521/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6993e-06
# Epoch 522/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1360e-06
# Epoch 523/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9198e-06
# Epoch 524/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8730e-06
# Epoch 525/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4820e-06
# Epoch 526/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3854e-06
# Epoch 527/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0882e-06
# Epoch 528/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9005e-06
# Epoch 529/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1819e-06
# Epoch 530/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7092e-06
# Epoch 531/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2699e-06
# Epoch 532/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0254e-06
# Epoch 533/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7010e-06
# Epoch 534/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5278e-06
# Epoch 535/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3327e-06
# Epoch 536/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3053e-06
# Epoch 537/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2868e-06
# Epoch 538/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4360e-06
# Epoch 539/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5748e-06
# Epoch 540/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8955e-06
# Epoch 541/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1356e-06
# Epoch 542/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6119e-06
# Epoch 543/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8126e-06
# Epoch 544/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0245e-06
# Epoch 545/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5614e-06
# Epoch 546/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2462e-06
# Epoch 547/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7792e-06
# Epoch 548/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5863e-06
# Epoch 549/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4398e-06
# Epoch 550/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5481e-06
# Epoch 551/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9500e-06
# Epoch 552/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9495e-06
# Epoch 553/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4900e-06
# Epoch 554/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3977e-06
# Epoch 555/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5504e-06
# Epoch 556/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7885e-06
# Epoch 557/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7911e-06
# Epoch 558/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1978e-06
# Epoch 559/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5733e-07
# Epoch 560/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 8.5019e-07
# Epoch 561/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 8.9906e-07
# Epoch 562/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0323e-06
# Epoch 563/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3525e-06
# Epoch 564/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7682e-06
# Epoch 565/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4160e-06
# Epoch 566/1000
# ...
# Epoch 813/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1558e-06
# Epoch 814/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.0778e-07
# Epoch 815/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6458e-07
# Epoch 816/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 8.7421e-07
# Epoch 817/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0232e-06
# Epoch 818/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1873e-06
# Epoch 819/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4617e-06
# Epoch 820/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7102e-06
# Epoch 821/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2116e-06
# Epoch 822/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6532e-06
# Epoch 823/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0651e-06
# Epoch 824/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7847e-06
# Epoch 825/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0897e-06
# Epoch 826/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5107e-06
# Epoch 827/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3644e-06
# Epoch 828/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8404e-06
# Epoch 829/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0121e-06
# Epoch 830/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2516e-06
# Epoch 831/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8401e-06
# Epoch 832/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8668e-06
# Epoch 833/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7832e-06
# Epoch 834/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2507e-06
# Epoch 835/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.0176e-07
# Epoch 836/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.7494e-07
# Epoch 837/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1821e-07
# Epoch 838/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 7.8082e-07
# Epoch 839/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9824e-07
# Epoch 840/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1535e-06
# Epoch 841/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4541e-06
# Epoch 842/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8918e-06
# Epoch 843/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2311e-06
# Epoch 844/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7428e-06
# Epoch 845/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3682e-06
# Epoch 846/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2934e-06
# Epoch 847/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1017e-06
# Epoch 848/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9322e-06
# Epoch 849/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8822e-06
# Epoch 850/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1862e-06
# Epoch 851/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 8.5471e-07
# Epoch 852/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0387e-07
# Epoch 853/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1218e-07
# Epoch 854/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2532e-07
# Epoch 855/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1118e-06
# Epoch 856/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5708e-06
# Epoch 857/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3045e-06
# Epoch 858/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7722e-06
# Epoch 859/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8329e-06
# Epoch 860/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2154e-06
# Epoch 861/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8093e-06
# Epoch 862/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5506e-06
# Epoch 863/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8986e-06
# Epoch 864/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5989e-06
# Epoch 865/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3831e-06
# Epoch 866/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3844e-06
# Epoch 867/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1180e-06
# Epoch 868/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4713e-06
# Epoch 869/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9016e-06
# Epoch 870/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4398e-06
# Epoch 871/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1494e-06
# Epoch 872/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.8479e-07
# Epoch 873/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.2241e-07
# Epoch 874/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4235e-07
# Epoch 875/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0435e-06
# Epoch 876/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2286e-06
# Epoch 877/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5134e-06
# Epoch 878/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8843e-06
# Epoch 879/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3539e-06
# Epoch 880/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7604e-06
# Epoch 881/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0614e-06
# Epoch 882/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9950e-06
# Epoch 883/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1101e-06
# Epoch 884/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7543e-06
# Epoch 885/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3219e-06
# Epoch 886/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6776e-06
# Epoch 887/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3900e-06
# Epoch 888/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1534e-06
# Epoch 889/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1241e-06
# Epoch 890/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0928e-06
# Epoch 891/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1616e-06
# Epoch 892/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1712e-06
# Epoch 893/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2746e-06
# Epoch 894/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4227e-06
# Epoch 895/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8543e-06
# Epoch 896/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3509e-06
# Epoch 897/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7192e-06
# Epoch 898/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3992e-06
# Epoch 899/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7922e-06
# Epoch 900/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2860e-06
# Epoch 901/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0812e-06
# Epoch 902/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2937e-06
# Epoch 903/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2591e-06
# Epoch 904/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0444e-06
# Epoch 905/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8107e-06
# Epoch 906/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0197e-06
# Epoch 907/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4275e-06
# Epoch 908/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5695e-06
# Epoch 909/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0011e-06
# Epoch 910/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 7.6505e-07
# Epoch 911/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3269e-07
# Epoch 912/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2615e-07
# Epoch 913/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7271e-07
# Epoch 914/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3332e-07
# Epoch 915/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0608e-06
# Epoch 916/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4483e-06
# Epoch 917/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8243e-06
# Epoch 918/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2825e-06
# Epoch 919/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3989e-06
# Epoch 920/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4815e-06
# Epoch 921/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1049e-06
# Epoch 922/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8369e-06
# Epoch 923/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4631e-06
# Epoch 924/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4127e-06
# Epoch 925/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5631e-06
# Epoch 926/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0275e-06
# Epoch 927/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3806e-06
# Epoch 928/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6046e-06
# Epoch 929/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4911e-06
# Epoch 930/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3731e-06
# Epoch 931/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4674e-06
# Epoch 932/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7612e-06
# Epoch 933/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0559e-06
# Epoch 934/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9342e-06
# Epoch 935/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6236e-06
# Epoch 936/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0148e-06
# Epoch 937/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6356e-06
# Epoch 938/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2920e-06
# Epoch 939/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1505e-06
# Epoch 940/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0330e-06
# Epoch 941/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0390e-06
# Epoch 942/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0513e-06
# Epoch 943/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1750e-06
# Epoch 944/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3010e-06
# Epoch 945/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5644e-06
# Epoch 946/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8290e-06
# Epoch 947/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3061e-06
# Epoch 948/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8302e-06
# Epoch 949/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4720e-06
# Epoch 950/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4519e-06
# Epoch 951/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7680e-06
# Epoch 952/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9424e-06
# Epoch 953/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3294e-06
# Epoch 954/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.7031e-07
# Epoch 955/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6781e-07
# Epoch 956/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 6.8727e-07
# Epoch 957/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 6.8337e-07
# Epoch 958/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7576e-07
# Epoch 959/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.5761e-07
# Epoch 960/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2575e-06
# Epoch 961/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5595e-06
# Epoch 962/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9037e-06
# Epoch 963/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2801e-06
# Epoch 964/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8640e-06
# Epoch 965/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0622e-06
# Epoch 966/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0227e-06
# Epoch 967/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5279e-06
# Epoch 968/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3685e-06
# Epoch 969/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3762e-06
# Epoch 970/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8015e-06
# Epoch 971/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7586e-06
# Epoch 972/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5533e-06
# Epoch 973/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0606e-06
# Epoch 974/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7326e-06
# Epoch 975/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4327e-06
# Epoch 976/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2668e-06
# Epoch 977/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1561e-06
# Epoch 978/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1317e-06
# Epoch 979/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1555e-06
# Epoch 980/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2511e-06
# Epoch 981/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3893e-06
# Epoch 982/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5969e-06
# Epoch 983/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8154e-06
# Epoch 984/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0798e-06
# Epoch 985/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2512e-06
# Epoch 986/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4189e-06
# Epoch 987/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4341e-06
# Epoch 988/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6736e-06
# Epoch 989/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5953e-06
# Epoch 990/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3412e-06
# Epoch 991/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7531e-06
# Epoch 992/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4407e-06
# Epoch 993/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1517e-06
# Epoch 994/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0572e-06
# Epoch 995/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 9.7178e-07
# Epoch 996/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9005e-07
# Epoch 997/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8141e-07
# Epoch 998/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0353e-06
# Epoch 999/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0529e-06
# Epoch 1000/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1910e-06

# %%
#  Combine training and testing datasets
combined_set = np.concatenate((train_data, test_data), axis=1)

# %%
#  Evaluate model at each week for the test set
evaluated_weeks = []
for i in range(0, test_data.shape[1]):
    input_series = combined_set[0:, i:i + 77]

    X_test = input_series[0:, :-1].reshape(1, input_series.shape[1] - 1, 7)
    Y_test = input_series[0:, -1:][0]

    result = model.evaluate(x=X_test, y=Y_test, verbose=0)
    evaluated_weeks.append(result)

# %%
#  Plot MSE for all evaluated weeks
ax = pd.Series(evaluated_weeks).plot(drawstyle="steps-post",
                                     figsize=(14, 4),
                                     color='#2c3e50',
                                     grid=True,
                                     title='Mean Squared Error (MSE) for Test Data')

ax.set_xticks(range(0, len(evaluated_weeks)))
ax.set_xlabel("Predicted Week")
ax.set_ylabel("MSE")
plt.show()

# %% [markdown]
# ## Interpreting Model Results

# %% [markdown]
# ### Make Predictions

# %%
#  Make predictions for each of the 19 weeks
#  in the test set
predicted_weeks = []
for i in range(0, test_data.shape[1]):
    input_series = combined_set[0:, i:i + 76]
    predicted_weeks.append(model.predict(input_series))

# %%
#  Flatten `predicted_weeks` to get a list
#  of predictions for each day in the 19 weeks
predicted_days = []
for week in predicted_weeks:
    predicted_days += list(week[0])

# %%
#  Create list of dates associated with predictions
last_day = datetime.strptime(train['date'].max(), '%Y-%m-%d')
list_of_days = []
for days in range(1, len(predicted_days) + 1):
    D = (last_day + timedelta(days=days)).strftime('%Y-%m-%d')
    list_of_days.append(D)

# %%
#  Create dataframe with predicted values
predicted = pd.DataFrame({
    'date': list_of_days,
    'close_point_relative_normalization': predicted_days
})
predicted.head()
# Out:
#          date  close_point_relative_normalization
# 0  2017-06-25                            0.000939
# 1  2017-06-26                            0.015341
# 2  2017-06-27                            0.067250
# 3  2017-06-28                            0.057250
# 4  2017-06-29                            0.062929

# %%
#  Convert `date` variable to datetime
predicted['date'] = predicted['date'].apply(
    lambda x: datetime.strptime(x, '%Y-%m-%d'))

test['date'] = test['date'].apply(
    lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
def plot_two_series(A, B, variable, title):
    """Plot two series using the same `date` index. 
    
    Parameters
    ----------
    A, B: pd.DataFrame
        Dataframe with a `date` key and a variable
        passed in the `variable` parameter. Parameter A
        represents the "Observed" series and B the "Predicted"
        series. These will be labelled respectively. 
    
    variable: str
        Variable to use in plot.
    
    title: str
        Plot title.
    """
    plt.figure(figsize=(14, 4))
    plt.xlabel('Observed and predicted')

    ax1 = A.set_index('date')[variable].plot(
        color='#d35400', grid=True, label='Observed', title=title)

    ax2 = B.set_index('date')[variable].plot(
        color='grey', grid=True, label='Predicted')
    
    ax1.set_xlabel("Predicted Week")
    ax1.set_ylabel("Predicted Values")

    plt.legend()
    plt.show()

# %%
#  Plot predicted normalized prices
#  against actual normalized prices
plot_two_series(A=test[:-3],
                B=predicted,
                variable='close_point_relative_normalization',
                title='Normalized Predictions per Week')

# %% [markdown]
# ### De-normalize Predictions

# %%
#  Add variable `iso_week` by stripping the Year and Week from `date`
predicted['iso_week'] = predicted['date'].apply(
    lambda x: x.strftime('%Y-%U'))

# %%
def denormalize(reference, series,
                normalized_variable='close_point_relative_normalization',
                denormalized_variable='close'):
    """Denormalize the values for a given series.

    Parameters
    ----------
    reference: pd.DataFrame
        DataFrame to use as reference. This dataframe
        contains both a week index and the USD price
        reference that we are interested on.

    series: pd.DataFrame
        DataFrame with the predicted series. The
        DataFrame must have the same columns as the
        `reference` dataset.

    normalized_variable: str, default 'close_point_relative_normalization'
        Variable to use in normalization.

    denormalized_variable: str, default `close`
        Variable to use in de-normalization.

    Returns
    -------
    A modified DataFrame with the new variable provided
    in `denormalized_variable` parameter.
    """
    week_values = reference[reference['iso_week'] == series['iso_week'].values[0]]
    last_value = week_values[denormalized_variable].values[0]
    series[denormalized_variable] = last_value * (series[normalized_variable] + 1)

    return series

# %%
#  Denormalize predictions
predicted_close = predicted.groupby('iso_week').apply(
    lambda x: denormalize(test[:-3], x))

# %%
#  Plot denormalized predictions and observed closing prices in test set
plot_two_series(A=test[:-3],
                B=predicted_close,
                variable='close',
                title='De-normalized Predictions per Week')

# %% [markdown]
# ### Calculate RMSE and MAPE

# %%
A = test[:-3]['close_point_relative_normalization']
B = predicted_close['close_point_relative_normalization']
print(f'Normalized RMSE: {rmse(A, B):.2f}')
# Out:
# Normalized RMSE: 0.10

# %%
A = test[:-3]['close']
B = predicted_close['close']

print(f'De-normalized RMSE: {rmse(A, B):.2f}')
print(f'De-normalized MAPE: {mape(A, B):.2f}')
# Out:
# De-normalized RMSE: 352.80
# De-normalized MAPE: 6.57
